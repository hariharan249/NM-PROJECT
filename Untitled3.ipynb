# %%
from google.colab import drive
drive.mount('/content/drive')
import os

# List the contents of the root folder to see if MyDrive exists
os.listdir('/content/drive/mydrive/file/Dataset')

# Now list the contents of MyDrive to find your folder
os.listdir('/content/drive/MyDrive/file/Dataset')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-1c06ce300e57> in <cell line: 0>()
#       7
#       8 # Now list the contents of MyDrive to find your folder
# ----> 9 os.listdir('/content/drive/MyDrive/file/Dataset')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/file/Dataset'
